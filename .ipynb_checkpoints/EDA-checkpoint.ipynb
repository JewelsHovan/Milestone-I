# %%
# !ls ED
# Out:
# diagnosis.csv edstays.csv   triage.csv    vitalsign.csv

# %%
# !ls HOSP
# Out:
# admissions.csv transfers.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# utility functions
from utils import nunique_per_cat

# %%
ed_stays = pd.read_csv("ED/edstays.csv")
admissions = pd.read_csv("HOSP/admissions.csv")
transfers = pd.read_csv("HOSP/transfers.csv")

print(f'Shape of Ed Stays table: {ed_stays.shape}')
ed_stays.head()
# Out:
# Shape of Ed Stays table: (425087, 9)
#    subject_id     hadm_id   stay_id               intime              outtime  \
# 0    10000032  22595853.0  33258284  2180-05-06 19:17:00  2180-05-06 23:30:00
# 1    10000032  22841357.0  38112554  2180-06-26 15:54:00  2180-06-26 21:31:00
# 2    10000032  25742920.0  35968195  2180-08-05 20:58:00  2180-08-06 01:44:00
# 3    10000032  29079034.0  32952584  2180-07-22 16:24:00  2180-07-23 05:54:00
# 4    10000032  29079034.0  39399961  2180-07-23 05:54:00  2180-07-23 14:00:00
#
#   gender   race arrival_transport disposition
# 0      F  WHITE         AMBULANCE    ADMITTED
# 1      F  WHITE         AMBULANCE    ADMITTED
# 2      F  WHITE         AMBULANCE    ADMITTED
# 3      F  WHITE         AMBULANCE        HOME
# 4      F  WHITE         AMBULANCE    ADMITTED

# %%
print(f'Shape Admissions table: {admissions.shape}')
admissions.head()
# Out:
# Shape Admissions table: (546028, 16)
#    subject_id   hadm_id            admittime            dischtime deathtime  \
# 0    10000032  22595853  2180-05-06 22:23:00  2180-05-07 17:15:00       NaN
# 1    10000032  22841357  2180-06-26 18:27:00  2180-06-27 18:49:00       NaN
# 2    10000032  25742920  2180-08-05 23:44:00  2180-08-07 17:50:00       NaN
# 3    10000032  29079034  2180-07-23 12:35:00  2180-07-25 17:55:00       NaN
# 4    10000068  25022803  2160-03-03 23:16:00  2160-03-04 06:26:00       NaN
#
#    admission_type admit_provider_id      admission_location  \
# 0          URGENT            P49AFC  TRANSFER FROM HOSPITAL
# 1        EW EMER.            P784FA          EMERGENCY ROOM
# 2        EW EMER.            P19UTS          EMERGENCY ROOM
# 3        EW EMER.            P06OTX          EMERGENCY ROOM
# 4  EU OBSERVATION            P39NWO          EMERGENCY ROOM
#
#   discharge_location insurance language marital_status   race  \
# 0               HOME  Medicaid  English        WIDOWED  WHITE
# 1               HOME  Medicaid  English        WIDOWED  WHITE
# 2            HOSPICE  Medicaid  English        WIDOWED  WHITE
# 3               HOME  Medicaid  English        WIDOWED  WHITE
# 4                NaN       NaN  English         SINGLE  WHITE
#
#              edregtime            edouttime  hospital_expire_flag
# 0  2180-05-06 19:17:00  2180-05-06 23:30:00                     0
# 1  2180-06-26 15:54:00  2180-06-26 21:31:00                     0
# 2  2180-08-05 20:58:00  2180-08-06 01:44:00                     0
# 3  2180-07-23 05:54:00  2180-07-23 14:00:00                     0
# 4  2160-03-03 21:55:00  2160-03-04 06:26:00                     0

# %%
print(f'Shape of Ed Stays table: {transfers.shape}')
transfers.head()
# Out:
# Shape of Ed Stays table: (2413589, 7)
#    subject_id     hadm_id  transfer_id  eventtype              careunit  \
# 0    10000032  22595853.0     33258284         ED  Emergency Department
# 1    10000032  22595853.0     35223874      admit            Transplant
# 2    10000032  22595853.0     36904543  discharge               UNKNOWN
# 3    10000032  22841357.0     34100253  discharge               UNKNOWN
# 4    10000032  22841357.0     34703856      admit            Transplant
#
#                 intime              outtime
# 0  2180-05-06 19:17:00  2180-05-06 23:30:00
# 1  2180-05-06 23:30:00  2180-05-07 17:21:27
# 2  2180-05-07 17:21:27                  NaN
# 3  2180-06-27 18:49:12                  NaN
# 4  2180-06-26 21:31:00  2180-06-27 18:49:12

# %% [markdown]
# ## Exploring Ed Stays Table

# %%
ed_stays.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425087 entries, 0 to 425086
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   subject_id         425087 non-null  int64
#  1   hadm_id            203016 non-null  float64
#  2   stay_id            425087 non-null  int64
#  3   intime             425087 non-null  object
#  4   outtime            425087 non-null  object
#  5   gender             425087 non-null  object
#  6   race               425087 non-null  object
#  7   arrival_transport  425087 non-null  object
#  8   disposition        425087 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 29.2+ MB

# %%
nunique_per_cat(ed_stays)
# Out:
# [('intime', 422817),
#  ('outtime', 423227),
#  ('gender', 2),
#  ('race', 33),
#  ('arrival_transport', 5),
#  ('disposition', 8)]

# %%
# convert the time columns into datetime objects for analysis
ed_stays['intime'] = pd.to_datetime(ed_stays['intime'])
ed_stays['outtime'] = pd.to_datetime(ed_stays['outtime'])

# %%
# compute the length of stay
ed_stays['length_of_stay'] = (ed_stays['outtime'] - ed_stays['intime']).dt.total_seconds() / 60 # we'll use default in minutes
# for hours
ed_stays['length_of_stay_hour'] = ed_stays['length_of_stay'] / 60

ed_stays[["length_of_stay", 'length_of_stay_hour']].head(3)
# Out:
#    length_of_stay  length_of_stay_hour
# 0           253.0             4.216667
# 1           337.0             5.616667
# 2           286.0             4.766667

# %% [markdown]
# ### Race-Based Analysis of Length of Stay
# Question: Are there racial disparities in the length of ED stay?

# %%
plt.figure(figsize=(10,6))
ed_stays.boxplot(column='length_of_stay_hour', by='race', grid=False, showfliers=False)
plt.title('ED Length of Stay by Race')
plt.suptitle('')  # Remove automatic title
plt.xlabel('Race')
plt.ylabel('Length of Stay (Hours)')
plt.xticks(rotation=45)
plt.savefig("visualizations/ED-Stay-By-Race.png")
plt.show()

# %%
# can see race breakdown
ed_stays['race'].value_counts()[:5].plot.bar()
plt.title("Top 5 Races admitted into ED");
plt.show()

# %% [markdown]
# ### Distribution of Length of Stay
#
# Question: What is the distribution of the length of stay (time) in the ED?

# %%
ed_stays['length_of_stay_hour'].max()
# Out:
# 493.06944444444446

# %%
# lets filter extreme outlieres out
Q1 = ed_stays['length_of_stay_hour'].quantile(0.25)
Q3 = ed_stays['length_of_stay_hour'].quantile(0.75)

# computing the IQR
IQR = Q3 - Q1

# we compute the bounds by 1.5 the IQR we could be more restrictive if less
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# filter through boolean indexing
filtered_data = ed_stays[(ed_stays['length_of_stay_hour'] >= lower_bound) & (ed_stays['length_of_stay_hour'] <= upper_bound)]

# create the boxplot
plt.figure(figsize=(8, 6))
g = sns.boxplot(y=filtered_data['length_of_stay_hour'])
g.set_title('Boxplot of Length of Stay in Hours in the ED')
g.set_ylabel("Length of Stay in Hours")
plt.savefig("visualizations/Boxplot-length-of-stay.png")
plt.show()

# %% [markdown]
# Note: The median of the legnth of stay is about 5 hours

# %%
# a violin plot to allow to see the shape of the distribution in terms of frequency
g = sns.violinplot(x = filtered_data['length_of_stay_hour'], fill=True)
g.set_title('Violin of Length of Stay in Hours in the ED')
g.set_xlabel("Length of Stay in Hours")
plt.savefig("visualizations/violin-length-of-stay.png")
plt.show()

# %%
g = sns.kdeplot(x = filtered_data['length_of_stay_hour'], fill=True)
g.set_title('Violin of Length of Stay in Hours')
g.set_xlabel("Length of Stay in Hours")
plt.show()

# %% [markdown]
# We see that the distribution appears to be a right skewed normal distribution. This makes sense, as most patients in for about 2.5 to 7.5 hours. Afterwards there might be cases where long observation is needed and the patient needs to stay longer.

# %% [markdown]
# ### Patient Flow by Time of Day
#
# Question: When are most patients arriving and leaving the ED?

# %%
# extract the hour of arrival and departure
ed_stays['arrival_hour'] = ed_stays['intime'].dt.hour
ed_stays['departure_hour'] = ed_stays['outtime'].dt.hour

# now plot number of arrivals and departures by hour
plt.figure(figsize=(10,6))
ed_stays['arrival_hour'].value_counts().sort_index().plot(kind='line', label='Arrivals', color='green')
ed_stays['departure_hour'].value_counts().sort_index().plot(kind='line', label='Departures', color='red')
plt.title('Patient Arrivals and Departures by Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Patients')
plt.legend()
plt.savefig('visualizations/Arrivals-Departures-by-hour.png')
plt.show()

# %% [markdown]
# We can see the number of arrivals peaks around 10-12, which makes sense as it is the peak of the day with the most activity. We can see that the departures lags behind the arrivals which also is a sanity check

# %% [markdown]
# ### Patient Disposition Analysis
# Question: How are patients leaving the ED (e.g., admitted, discharged, transferred)?

# %%
plt.figure(figsize=(8,6))
ed_stays['disposition'].value_counts().plot(kind='bar', color='purple', alpha=0.7)
plt.title('Patient Disposition from the ED')
plt.xlabel('Disposition')
plt.ylabel('Number of Patients')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The majority go back home after the stay, the the next biggest group are admitted into the hospital.
#
# The rest are transfered or leave

# %%
import matplotlib.pyplot as plt

# Calculate average length of stay per disposition
disposition_los = ed_stays.groupby('disposition')['length_of_stay_hour'].mean()

# Get the count of each disposition
disposition_counts = ed_stays['disposition'].value_counts()

# Create the bubble plot
plt.figure(figsize=(8,6))

# The size of the bubbles is proportional to the average length of stay
bubble_sizes = disposition_los * 100  # Adjust scaling factor for better visibility

# Create scatter plot (bubble plot)
plt.scatter(disposition_counts.index, disposition_counts.values, s=bubble_sizes, alpha=0.6, color='blue', edgecolor='black', linewidth=1)

plt.title('Patient Disposition vs. Average Length of Stay')
plt.xlabel('Disposition')
plt.ylabel('Number of Patients')
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(10,6))
ed_stays.boxplot(column='length_of_stay_hour', by='arrival_transport', grid=False, showfliers=False)
plt.title('ED Length of Stay by Arrival Transport')
plt.suptitle('') 
plt.xlabel('Arrival Transport')
plt.ylabel('Length of Stay (Hours)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Gender Difference in Length of Stay
#
# Question: Is there a differnece in the length of stay between genders?

# %%
plt.figure(figsize=(8,6))
ed_stays.boxplot(column='length_of_stay_hour', by='gender', grid=False, showfliers=False)
plt.title('ED Length of Stay by Gender')
plt.suptitle('')  # Remove automatic title
plt.xlabel('Gender')
plt.ylabel('Length of Stay (Hours)')
plt.show()

# %% [markdown]
# There appears to be no differences in the length of stsay by gender.

# %% [markdown]
# ### Seasonal or Monthly Trends
# Question: Are there any seasonal trends in ED stays (e.g., more patients in the winter or in the summer)?

# %%
ed_stays['month'] = ed_stays['intime'].dt.month

# we can create a mapping 
months_mapping = {
    1: "January",
    2: "February",
    3: "March",
    4: "April",
    5: "May",
    6: "June",
    7: "July",
    8: "August",
    9: "September",
    10: "October",
    11: "November",
    12: "December"
}

plt.figure(figsize=(8,4))

stays_by_month = ed_stays['month'].value_counts().sort_index()

plt.bar(months_mapping.values(), stays_by_month, color='orange')
plt.title('Number of ED Patients by Month')
plt.xticks(rotation = 90)
plt.xlabel('Month')
plt.ylabel('Number of Patients')
plt.ylim(30000, 38000)
plt.show()

# %% [markdown]
# It's hard to see the differences in the absolute counts per month.
#
# Trying cuberoot and log doesn't help much.
#
# We can use percent change to see the relative change over the year

# %%
plt.figure(figsize=(8, 4))

# compute the percetnage change by month
percentage_change = stays_by_month.pct_change().fillna(0) * 100

# plot the percentages chagne
plt.bar(months_mapping.values(), percentage_change, color='orange')
plt.title("Percentage Change in Number of ED Patients by Month")
plt.xticks(rotation = 90)
plt.xlabel("Month")
plt.ylabel("Percentage Change (%)")
plt.show()

# %% [markdown]
# We see an interesting pattern of fluctuating number of patients each month. It appears there is a cycle of percentage change up and down every two months.

# %% [markdown]
# We could also

# %%
plt.figure(figsize=(8,4))
# calculate cumulative sum
cumulative_stays_by_month = stays_by_month.cumsum()

# plot the cumulative sum over time
plt.bar(months_mapping.values(), cumulative_stays_by_month, color='orange')
plt.title('Cumulative Number of ED Patients by Month')
plt.xticks(rotation = 90)
plt.xlabel('Month')
plt.ylabel('Cumulative Number of Patients')
plt.show()

# %%
plt.figure(figsize=(8,4))

# Sort by number of patients
sorted_stays_by_month = stays_by_month.sort_values()

# Plot with color gradient (e.g., darker colors for higher values)
plt.bar(sorted_stays_by_month.index.map(months_mapping), sorted_stays_by_month, color=plt.cm.Oranges(np.linspace(0.3, 1, len(stays_by_month))))
plt.title('Number of ED Patients by Month')
plt.xticks(rotation = 90)
plt.xlabel('Month')
plt.ylabel('Number of Patients')
plt.show()

# %% [markdown]
# ## Exploring Admissions Table

# %%
admissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546028 entries, 0 to 546027
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   subject_id            546028 non-null  int64
#  1   hadm_id               546028 non-null  int64
#  2   admittime             546028 non-null  object
#  3   dischtime             546028 non-null  object
#  4   deathtime             11790 non-null   object
#  5   admission_type        546028 non-null  object
#  6   admit_provider_id     546024 non-null  object
#  7   admission_location    546027 non-null  object
#  8   discharge_location    396210 non-null  object
#  9   insurance             536673 non-null  object
#  10  language              545253 non-null  object
#  11  marital_status        532409 non-null  object
#  12  race                  546028 non-null  object
#  13  edregtime             379240 non-null  object
#  14  edouttime             379240 non-null  object
#  15  hospital_expire_flag  546028 non-null  int64
# dtypes: int64(3), object(13)
# memory usage: 66.7+ MB

# %%
# number of unique labels per category
nunique_per_cat(admissions)
# Out:
# [('admittime', 534919),
#  ('dischtime', 528871),
#  ('deathtime', 11788),
#  ('admission_type', 9),
#  ('admit_provider_id', 2045),
#  ('admission_location', 11),
#  ('discharge_location', 13),
#  ('insurance', 5),
#  ('language', 25),
#  ('marital_status', 4),
#  ('race', 33),
#  ('edregtime', 372692),
#  ('edouttime', 372755)]

# %%
admissions.race.unique() # into 5 overall catgoeis
# Out:
# array(['WHITE', 'OTHER', 'BLACK/AFRICAN AMERICAN', 'UNABLE TO OBTAIN',
#        'UNKNOWN', 'WHITE - RUSSIAN', 'BLACK/CAPE VERDEAN',
#        'NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER', 'PORTUGUESE',
#        'WHITE - OTHER EUROPEAN', 'HISPANIC/LATINO - PUERTO RICAN',
#        'ASIAN', 'ASIAN - CHINESE', 'HISPANIC/LATINO - DOMINICAN',
#        'HISPANIC/LATINO - SALVADORAN', 'BLACK/AFRICAN',
#        'HISPANIC/LATINO - GUATEMALAN', 'ASIAN - SOUTH EAST ASIAN',
#        'WHITE - BRAZILIAN', 'SOUTH AMERICAN', 'HISPANIC OR LATINO',
#        'ASIAN - KOREAN', 'BLACK/CARIBBEAN ISLAND',
#        'HISPANIC/LATINO - MEXICAN', 'PATIENT DECLINED TO ANSWER',
#        'HISPANIC/LATINO - CUBAN', 'AMERICAN INDIAN/ALASKA NATIVE',
#        'MULTIPLE RACE/ETHNICITY', 'WHITE - EASTERN EUROPEAN',
#        'HISPANIC/LATINO - HONDURAN', 'HISPANIC/LATINO - CENTRAL AMERICAN',
#        'ASIAN - ASIAN INDIAN', 'HISPANIC/LATINO - COLUMBIAN'],
#       dtype=object)

# %%
# converting to datetimes
admissions['admittime'] = pd.to_datetime(admissions['admittime'])
admissions['dischtime'] = pd.to_datetime(admissions['dischtime'])
admissions['deathtime'] = pd.to_datetime(admissions['deathtime'])
admissions['edregtime'] = pd.to_datetime(admissions['edregtime'])
admissions['edouttime'] = pd.to_datetime(admissions['edouttime'])

# length of stay
admissions['admit_duration'] = (admissions['dischtime'] - admissions['admittime']).dt.total_seconds() / 60 # minutes
admissions['admit_duration_hours'] = admissions['admit_duration'] / 60
admissions['admit_duration_days'] = admissions['admit_duration_hours'] / 24

admissions[['admit_duration', 'admit_duration_hours', 'admit_duration_days']].head(3)
# Out:
#    admit_duration  admit_duration_hours  admit_duration_days
# 0          1132.0             18.866667             0.786111
# 1          1462.0             24.366667             1.015278
# 2          2526.0             42.100000             1.754167

# %%
# lets look at the dsitribution of duration spent admitted

# lets filter again
Q1 = admissions['admit_duration_hours'].quantile(0.25)
Q3 = admissions['admit_duration_hours'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

filtered_durations = admissions[(admissions['admit_duration_hours'] >= lower_bound) & (admissions['admit_duration_hours'] <= upper_bound)]

fig, axes = plt.subplots(2, 1, figsize=(12, 6))

sns.boxplot(x = 'admit_duration_hours', data = filtered_durations, ax = axes[0])
sns.violinplot(x = 'admit_duration_hours', data = filtered_durations, ax = axes[1])
plt.show()

# %% [markdown]
# It appears theres variation every day, you can see the large peaks at the every 24 hour mark, and its with gradual diminishing every day
#
# We can see that the IQR or 50% of the values fall between 1 to 4 days, showcasing that most patients stay within this time range. Then theres many right skewed outliers, those who stay for over 10 days at the hospital.

# %%
duration_by_type = admissions.groupby("admission_type")['admit_duration_hours'].agg(['mean', 'median', 'count'])

categories = duration_by_type.index

bar_width = 0.35
x = np.arange(len(categories))

fig, ax = plt.subplots(figsize=(10, 6))

ax.bar(x - bar_width/2, duration_by_type['mean'], bar_width, label='mean', color ='b')
ax.bar(x + bar_width/2, duration_by_type['median'], bar_width, label='median', color='y')

ax.set_xlabel("Admission Type")
ax.set_ylabel("Time in Hours")
ax.set_title("Mean and Median Comparison")
ax.set_xticks(x)
ax.set_xticklabels(categories, rotation=90)
ax.legend(loc='best')
plt.show()

# %% [markdown]
# # Merging Admissions and Ed Stays

# %%
# merge admissions and edstays

edstays_admissions = ed_stays.merge(admissions, on = 'subject_id', how = 'inner')

edstays_admissions.iloc[:, 3:].head()
# Out:
#                intime             outtime gender race_x arrival_transport  \
# 0 2180-05-06 19:17:00 2180-05-06 23:30:00      F  WHITE         AMBULANCE
# 1 2180-05-06 19:17:00 2180-05-06 23:30:00      F  WHITE         AMBULANCE
# 2 2180-05-06 19:17:00 2180-05-06 23:30:00      F  WHITE         AMBULANCE
# 3 2180-05-06 19:17:00 2180-05-06 23:30:00      F  WHITE         AMBULANCE
# 4 2180-06-26 15:54:00 2180-06-26 21:31:00      F  WHITE         AMBULANCE
#
#   disposition  length_of_stay  length_of_stay_hour  arrival_hour  \
# 0    ADMITTED           253.0             4.216667            19
# 1    ADMITTED           253.0             4.216667            19
# 2    ADMITTED           253.0             4.216667            19
# 3    ADMITTED           253.0             4.216667            19
# 4    ADMITTED           337.0             5.616667            15
#
#    departure_hour  ...  insurance  language marital_status race_y  \
# 0              23  ...   Medicaid   English        WIDOWED  WHITE
# 1              23  ...   Medicaid   English        WIDOWED  WHITE
# 2              23  ...   Medicaid   English        WIDOWED  WHITE
# 3              23  ...   Medicaid   English        WIDOWED  WHITE
# 4              21  ...   Medicaid   English        WIDOWED  WHITE
#
#             edregtime           edouttime hospital_expire_flag admit_duration  \
# 0 2180-05-06 19:17:00 2180-05-06 23:30:00                    0         1132.0
# 1 2180-06-26 15:54:00 2180-06-26 21:31:00                    0         1462.0
# 2 2180-08-05 20:58:00 2180-08-06 01:44:00                    0         2526.0
# 3 2180-07-23 05:54:00 2180-07-23 14:00:00                    0         3200.0
# 4 2180-05-06 19:17:00 2180-05-06 23:30:00                    0         1132.0
#
#   admit_duration_hours admit_duration_days
# 0            18.866667            0.786111
# 1            24.366667            1.015278
# 2            42.100000            1.754167
# 3            53.333333            2.222222
# 4            18.866667            0.786111
#
# [5 rows x 29 columns]

# %%
edstays_admissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2749695 entries, 0 to 2749694
# Data columns (total 32 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   subject_id            int64
#  1   hadm_id_x             float64
#  2   stay_id               int64
#  3   intime                datetime64[ns]
#  4   outtime               datetime64[ns]
#  5   gender                object
#  6   race_x                object
#  7   arrival_transport     object
#  8   disposition           object
#  9   length_of_stay        float64
#  10  length_of_stay_hour   float64
#  11  arrival_hour          int32
#  12  departure_hour        int32
#  13  month                 int32
#  14  hadm_id_y             int64
#  15  admittime             datetime64[ns]
#  16  dischtime             datetime64[ns]
#  17  deathtime             datetime64[ns]
#  18  admission_type        object
#  19  admit_provider_id     object
#  20  admission_location    object
#  21  discharge_location    object
#  22  insurance             object
#  23  language              object
#  24  marital_status        object
#  25  race_y                object
#  26  edregtime             datetime64[ns]
#  27  edouttime             datetime64[ns]
#  28  hospital_expire_flag  int64
#  29  admit_duration        float64
#  30  admit_duration_hours  float64
#  31  admit_duration_days   float64
# dtypes: datetime64[ns](7), float64(6), int32(3), int64(4), object(12)
# memory usage: 639.8+ MB

# %%
# The number of unique values per categorical column
nunique_per_cat(edstays_admissions)
# Out:
# [('gender', 2),
#  ('race_x', 33),
#  ('arrival_transport', 5),
#  ('disposition', 8),
#  ('admission_type', 9),
#  ('admit_provider_id', 1889),
#  ('admission_location', 11),
#  ('discharge_location', 13),
#  ('insurance', 5),
#  ('language', 25),
#  ('marital_status', 4),
#  ('race_y', 33)]

# %%
edstays_admissions.groupby("insurance")['length_of_stay'].mean().plot.bar();

# %%
edstays_admissions.groupby("race_x")['length_of_stay_hour'].mean().plot.bar()
# Out:
# <Axes: xlabel='race_x'>

# %%
edstays_admissions.groupby("gender")['length_of_stay_hour'].mean().plot.bar();

# %%
edstays_admissions.groupby("marital_status")['length_of_stay_hour'].mean().plot.bar();

# %%
edstays_admissions.groupby('admission_type')['length_of_stay_hour'].mean().plot.bar()
# Out:
# <Axes: xlabel='admission_type'>

# %% [markdown]
# ## Exploring Triage

# %%
triage_df = pd.read_csv("ED/triage.csv")

triage_df.head()
# Out:
#    subject_id   stay_id  temperature  heartrate  resprate  o2sat    sbp   dbp  \
# 0    10000032  32952584         97.8       87.0      14.0   97.0   71.0  43.0
# 1    10000032  33258284         98.4       70.0      16.0   97.0  106.0  63.0
# 2    10000032  35968195         99.4      105.0      18.0   96.0  106.0  57.0
# 3    10000032  38112554         98.9       88.0      18.0   97.0  116.0  88.0
# 4    10000032  39399961         98.7       77.0      16.0   98.0   96.0  50.0
#
#   pain  acuity                            chiefcomplaint
# 0    7     2.0                               Hypotension
# 1    0     3.0            Abd pain, Abdominal distention
# 2   10     3.0                           n/v/d, Abd pain
# 3   10     3.0                      Abdominal distention
# 4   13     2.0  Abdominal distention, Abd pain, LETHAGIC

# %%
triage_df.chiefcomplaint.nunique()
# Out:
# 60406

# %%
# some descriptive statistics
triage_df.describe()
# Out:
#          subject_id       stay_id    temperature      heartrate  \
# count  4.250870e+05  4.250870e+05  401672.000000  407997.000000
# mean   1.500871e+07  3.499735e+07      98.015046      85.079891
# std    2.878486e+06  2.888342e+06       4.008575      18.041690
# min    1.000003e+07  3.000001e+07       0.100000       1.000000
# 25%    1.251789e+07  3.249799e+07      97.500000      72.000000
# 50%    1.501628e+07  3.499395e+07      98.000000      84.000000
# 75%    1.749900e+07  3.750387e+07      98.600000      96.000000
# max    1.999999e+07  3.999996e+07     986.000000    1228.000000
#
#             resprate          o2sat            sbp            dbp  \
# count  404734.000000  404491.000000  406796.000000  405996.000000
# mean       17.565521      98.471888     135.395352      81.262126
# std         5.485706      17.040807     240.956408    1057.220031
# min         0.000000       0.000000       1.000000       0.000000
# 25%        16.000000      97.000000     120.000000      68.000000
# 50%        18.000000      99.000000     133.000000      77.000000
# 75%        18.000000     100.000000     148.000000      87.000000
# max      1820.000000    9322.000000  151103.000000  661672.000000
#
#               acuity
# count  418100.000000
# mean        2.625102
# std         0.708084
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         5.000000

# %% [markdown]
# It appears there are mistakes for certain entries
#
# -> For example heartrate cannot be 1228 bpm or sbp being 151103
#
# This is impossible we need to remove or fix these mistakes

# %%
from utils import min_max_for_cols

min_max_for_cols(triage_df)
# Out:
# subject_id - min: 10000032, max: 19999987
# stay_id - min: 30000012, max: 39999965
# temperature - min: 0.1, max: 986.0
# heartrate - min: 1.0, max: 1228.0
# resprate - min: 0.0, max: 1820.0
# o2sat - min: 0.0, max: 9322.0
# sbp - min: 1.0, max: 151103.0
# dbp - min: 0.0, max: 661672.0
# acuity - min: 1.0, max: 5.0

# %%
fig, axes = plt.subplots(4, 2, figsize=(14, 8))

axes = axes.ravel()
num_cols = ['temperature', 'heartrate', 'resprate', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp']

for i, col in enumerate(triage_df[num_cols].columns):
    g = sns.boxplot(x=col, data=triage_df, ax = axes[i])
    g.set_title(f'{col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Vital Signs Reference Ranges**
#
# **Temperature:**
#
# * Valid range: 95.0°F - 107.6°F (35°C - 42°C)
# * Normal range: 97.8°F - 99.1°F (36.5°C - 37.3°C)
# * Source: The average normal core temperature is generally considered to be between 97.8°F and 99.1°F (36.5°C to 37.3°C). Temperatures outside the wider range of 95.0°F - 107.6°F are likely errors or extreme medical emergencies.
#
# **Heart Rate:**
#
# * Valid range: 20 - 250 beats per minute
# * Normal range for adults: 60 - 100 beats per minute
# * Source: For adults, a normal resting heart rate is between 60 and 100 beats per minute (bpm). The wider range accounts for extreme bradycardia and tachycardia.
#
# **Respiratory Rate:**
#
# * Valid range: 4 - 60 breaths per minute
# * Normal range for adults: 12 - 20 breaths per minute
# * Source: A normal respiratory rate for an adult at rest is 12 to 20 breaths per minute.
#
# **Oxygen Saturation (O2sat):**
#
# * Valid range: 70% - 100%
# * Normal range: 95% - 100%
# * Source: Normal oxygen levels are greater than 92% on room air. Values below 70% are extremely rare and likely errors.
#
# **Systolic Blood Pressure (SBP):**
#
# * Valid range: 50 - 250 mmHg
# * Normal range for adults: 90 - 120 mmHg
# * Source: Normal blood pressure is between 90/60 mmHg and 120/80 mmHg.
#
# **Diastolic Blood Pressure (DBP):**
#
# * Valid range: 20 - 150 mmHg
# * Normal range for adults: 60 - 80 mmHg
# * Source: Normal blood pressure is between 90/60 mmHg and 120/80 mmHg
#
# **Sources:**
#
# * https://emedicine.medscape.com/article/2172054-overview?form=fpf
# * https://soteradigitalhealth.com/blog/vital-signs-how-to-measure-and-whats-the-normal-range
# * https://www.medicalnewstoday.com/articles/vital-signs
# * https://www.healthline.com/health/dangerous-heart-rate

# %%
# set thresholds based on reasonable medical ranges
valid_ranges = {
    'temperature': (95.0, 107.6),
    'heartrate': (20, 250),      
    'resprate': (4, 60),
    'o2sat': (70, 100),            
    'sbp': (50, 250),
    'dbp': (20, 150)               
}

# function to clean the outliers based on thresholds
def clean_outliers(df, column, valid_range):
    lower, upper = valid_range
    df[column] = df[column].apply(lambda x: x if lower <= x <= upper else None)  # Set outliers to None
    return df

# apply the cleaning to the appropriate columns
for column, valid_range in valid_ranges.items():
    triage_df = clean_outliers(triage_df, column, valid_range)

# drop rows with any remaining NaN values in the key columns (optional)
triage_cleaned = triage_df.dropna(subset=valid_ranges.keys())

# %%
triage_cleaned[num_cols].describe()
# Out:
#          temperature      heartrate       resprate      heartrate  \
# count  390799.000000  390799.000000  390799.000000  390799.000000
# mean       98.088897      84.953636      17.512279      84.953636
# std         0.948370      17.390274       2.229031      17.390274
# min        95.000000      20.000000       4.000000      20.000000
# 25%        97.600000      72.000000      16.000000      72.000000
# 50%        98.000000      84.000000      18.000000      84.000000
# 75%        98.600000      96.000000      18.000000      96.000000
# max       106.600000     250.000000      60.000000     250.000000
#
#             resprate          o2sat            sbp            dbp
# count  390799.000000  390799.000000  390799.000000  390799.000000
# mean       17.512279      98.418361     135.030745      77.474362
# std         2.229031       1.964901      22.059855      14.530137
# min         4.000000      70.000000      50.000000      20.000000
# 25%        16.000000      97.000000     120.000000      68.000000
# 50%        18.000000      99.000000     133.000000      77.000000
# 75%        18.000000     100.000000     148.000000      87.000000
# max        60.000000     100.000000     250.000000     150.000000

# %%
# we could explore the chief complaint and map to a smaller dimension of topics/keywords
triage_df.chiefcomplaint
# Out:
# 0                                      Hypotension
# 1                   Abd pain, Abdominal distention
# 2                                  n/v/d, Abd pain
# 3                             Abdominal distention
# 4         Abdominal distention, Abd pain, LETHAGIC
#                             ...
# 425082                                Abnormal MRI
# 425083                        Abd pain, Wound eval
# 425084                        Abd pain, Wound eval
# 425085        Altered mental status, Substance use
# 425086                                  HEAD BLEED
# Name: chiefcomplaint, Length: 425087, dtype: object

# %%
triage_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425087 entries, 0 to 425086
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   subject_id      425087 non-null  int64
#  1   stay_id         425087 non-null  int64
#  2   temperature     400846 non-null  float64
#  3   heartrate       407967 non-null  float64
#  4   resprate        404676 non-null  float64
#  5   o2sat           404301 non-null  float64
#  6   sbp             406535 non-null  float64
#  7   dbp             405254 non-null  float64
#  8   pain            412154 non-null  object
#  9   acuity          418100 non-null  float64
#  10  chiefcomplaint  425064 non-null  object
# dtypes: float64(7), int64(2), object(2)
# memory usage: 35.7+ MB

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

X = triage_cleaned[['temperature', 'heartrate', 'resprate', 'o2sat', 'sbp', 'dbp', 'acuity']]
X = X.dropna()

sc = StandardScaler()
sc.fit_transform(X)

# perform pca
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

X_pca[:5]
# Out:
# array([[-72.38999429,   4.71349844],
#        [-33.19549341, -13.04817022],
#        [-33.81728037,  19.83348868],
#        [-12.67277252,   7.76127454],
#        [-47.32897254,  -7.26863403]])

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1])
plt.show()

# %%
tsne = TSNE(n_components=2)
# tsne scales poorly -> use a sample
X_tnse = tsne.fit_transform(X.sample(1000, replace=True))

plt.scatter(X_tnse[:, 0], X_tnse[:, 1])
plt.show()

# %% [markdown]
# ### What is the distribution of acuity?

# %%
acuity_counts = triage_cleaned.acuity.value_counts()

acuity_counts
# Out:
# acuity
# 3.0    217232
# 2.0    130707
# 4.0     27592
# 1.0     14076
# 5.0      1036
# Name: count, dtype: int64

# %%
plt.bar(acuity_counts.index, acuity_counts)
plt.title("Numer of Cases per Acuity")
plt.show()

# %% [markdown]
# We could try to group length of stay with acuity level

# %%
# merging with admissions
admissions_triage = admissions.merge(triage_cleaned, on ='subject_id', how = 'inner')

admissions_triage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2543898 entries, 0 to 2543897
# Data columns (total 29 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   subject_id            int64
#  1   hadm_id               int64
#  2   admittime             datetime64[ns]
#  3   dischtime             datetime64[ns]
#  4   deathtime             datetime64[ns]
#  5   admission_type        object
#  6   admit_provider_id     object
#  7   admission_location    object
#  8   discharge_location    object
#  9   insurance             object
#  10  language              object
#  11  marital_status        object
#  12  race                  object
#  13  edregtime             datetime64[ns]
#  14  edouttime             datetime64[ns]
#  15  hospital_expire_flag  int64
#  16  admit_duration        float64
#  17  admit_duration_hours  float64
#  18  admit_duration_days   float64
#  19  stay_id               int64
#  20  temperature           float64
#  21  heartrate             float64
#  22  resprate              float64
#  23  o2sat                 float64
#  24  sbp                   float64
#  25  dbp                   float64
#  26  pain                  object
#  27  acuity                float64
#  28  chiefcomplaint        object
# dtypes: datetime64[ns](5), float64(10), int64(4), object(10)
# memory usage: 562.8+ MB

# %%
plt.figure(figsize=(10, 5))
admissions_triage.groupby('acuity')['admit_duration_hours'].mean().plot.bar(color='lightblue')
plt.xticks(rotation=0)
plt.title("Mean Length of Stay per Acuity")
plt.ylabel("Average Length of Stay in Hours")
plt.savefig('visualizations/mean-stay-per-acuity.png')
plt.show()

# %% [markdown]
# ## Exploring Diagnosis Table

# %%
diagnosis_df = pd.read_csv("ED/diagnosis.csv")

diagnosis_df.head()
# Out:
#    subject_id   stay_id  seq_num icd_code  icd_version  \
# 0    10000032  32952584        1     4589            9
# 1    10000032  32952584        2    07070            9
# 2    10000032  32952584        3      V08            9
# 3    10000032  33258284        1     5728            9
# 4    10000032  33258284        2    78959            9
#
#                                            icd_title
# 0                                    HYPOTENSION NOS
# 1  UNSPECIFIED VIRAL HEPATITIS C WITHOUT HEPATIC ...
# 2                         ASYMPTOMATIC HIV INFECTION
# 3                           OTH SEQUELA, CHR LIV DIS
# 4                                      OTHER ASCITES

# %%
diagnosis_df.icd_code.nunique()
# Out:
# 13199

# %%
diagnosis_df.icd_version.unique()
# Out:
# array([ 9, 10])

# %% [markdown]
# We verify there are the two icd versions 9 and 10

# %%
diagnosis_df.icd_version.value_counts()
# Out:
# icd_version
# 10    456035
# 9     443015
# Name: count, dtype: int64

# %%
diagnosis_icd9 = diagnosis_df[diagnosis_df['icd_version'] == 9]
diagnosis_icd10 = diagnosis_df[diagnosis_df['icd_version'] == 10]

diagnosis_icd9.icd_code.nunique(), diagnosis_icd10.icd_code.nunique()
# Out:
# (4684, 8526)

# %%
diagnosis_icd9.icd_code.head(10)
# Out:
# 0     4589
# 1    07070
# 2      V08
# 3     5728
# 4    78959
# 5    07070
# 6      V08
# 7     5715
# 8    78900
# 9      V08
# Name: icd_code, dtype: object

# %%
diagnosis_icd10.icd_code.head(10)
# Out:
# 16       R531
# 17        G20
# 18      R4182
# 19      F0390
# 23    S0181XD
# 24    V00131D
# 25    S025XXA
# 26    S0181XA
# 27    W1789XA
# 28    S098XXA
# Name: icd_code, dtype: object

# %%
top_50_diagnosis = diagnosis_icd10.icd_title.value_counts()[:50].reset_index()

top_50_diagnosis['pct'] = top_50_diagnosis['count'] / diagnosis_icd10.shape[0] * 100

top_50_diagnosis
# Out:
#                                             icd_title  count       pct
# 0                    Essential (primary) hypertension  21264  4.662800
# 1                             Chest pain, unspecified  13016  2.854167
# 2                          Unspecified abdominal pain  10504  2.303332
# 3      Type 2 diabetes mellitus without complications   8801  1.929896
# 4   Fall on same level, unspecified, initial encou...   7817  1.714123
# 5                                Dyspnea, unspecified   7080  1.552512
# 6        Alcohol abuse with intoxication, unspecified   6871  1.506683
# 7                                            Headache   6841  1.500104
# 8         Urinary tract infection, site not specified   5898  1.293322
# 9                                            Weakness   5871  1.287401
# 10                 Altered mental status, unspecified   5758  1.262622
# 11                               Syncope and collapse   5546  1.216135
# 12                            Dizziness and giddiness   5504  1.206925
# 13                 Long term (current) use of insulin   5278  1.157367
# 14                                      Low back pain   5202  1.140702
# 15                                 Fever, unspecified   4824  1.057814
# 16  Exposure to other specified factors, initial e...   4746  1.040710
# 17                                 Suicidal ideations   4650  1.019659
# 18  Major depressive disorder, single episode, uns...   4534  0.994222
# 19                    Pneumonia, unspecified organism   4425  0.970320
# 20                  Nausea with vomiting, unspecified   4220  0.925368
# 21                                   Other chest pain   3965  0.869451
# 22          Long term (current) use of anticoagulants   3884  0.851689
# 23             Pure hypercholesterolemia, unspecified   3840  0.842041
# 24  Oth places as the place of occurrence of the e...   3632  0.796430
# 25                              Diarrhea, unspecified   3589  0.787001
# 26                    Unspecified atrial fibrillation   3484  0.763976
# 27                                    Epigastric pain   3375  0.740075
# 28                  Acute kidney failure, unspecified   3056  0.670124
# 29                          Right lower quadrant pain   2931  0.642714
# 30                         Heart failure, unspecified   2871  0.629557
# 31                                              Cough   2738  0.600393
# 32           Gastrointestinal hemorrhage, unspecified   2645  0.579999
# 33                                       Palpitations   2500  0.548204
# 34                                Anemia, unspecified   2308  0.506102
# 35                           Left lower quadrant pain   2258  0.495137
# 36                          Right upper quadrant pain   2189  0.480007
# 37                                        Cervicalgia   2162  0.474086
# 38  Other specified injuries of head, initial enco...   1958  0.429353
# 39                      Anxiety disorder, unspecified   1953  0.428257
# 40                                Shortness of breath   1886  0.413565
# 41              Other specified soft tissue disorders   1854  0.406548
# 42  Striking against or struck by other objects, i...   1818  0.398654
# 43  Epilepsy, unsp, not intractable, without statu...   1807  0.396242
# 44                                        Dehydration   1793  0.393172
# 45                     Acute pharyngitis, unspecified   1771  0.388347
# 46  Car driver injured in collision w car in traf,...   1767  0.387470
# 47  Oth surgical procedures cause abn react/compl,...   1647  0.361156
# 48                                 Anesthesia of skin   1632  0.357867
# 49                           Tachycardia, unspecified   1632  0.357867

# %%
plt.figure(figsize=(10, 6))
plt.bar(top_50_diagnosis.icd_title[:10], top_50_diagnosis.pct[:10])
plt.title("Top 10 Frequent Diagnosis")
plt.xticks(rotation = 90)
plt.ylabel("Percentage (%)")
plt.show()
